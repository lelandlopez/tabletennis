# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../csv/working.csv')
df
# Out:
#               id  last_Player_Score_cumsum_left  \
# 0       6civ8qu0                           65.0
# 1       fNmz9PPg                           54.0
# 2       UwkKodSS                           59.0
# 3       E3G2nI5H                           56.0
# 4       jcZOXZpQ                           99.0
# ...          ...                            ...
# 160970  l2lHC3fl                         1221.0
# 160971  dSiPAsP0                          983.0
# 160972  rPmLBN9f                          377.0
# 160973  ABkDDqur                          714.0
# 160974  ShBbkFuQ                          375.0
#
#         last_Player_ScoretoScore_cumsum_left  last_Player_Win_cumsum_left  \
# 0                                       13.0                          9.0
# 1                                       66.0                          5.0
# 2                                       13.0                          8.0
# 3                                       13.0                          7.0
# ...

# %%
df.columns
# Out:
# Index(['id', 'last_Player_Score_cumsum_left',
#        'last_Player_ScoretoScore_cumsum_left', 'last_Player_Win_cumsum_left',
#        'last_Player_Games_len_cumsum_left',
#        'last_Player_Score_Player_num_match_ave_left',
#        'last_Player_ScoretoScore_Player_num_match_ave_left',
#        'last_Player_Win_Player_num_match_ave_left',
#        'last_Player_Games_len_Player_num_match_ave_left',
#        'last_Player_Score_Games_len_ave_left',
#        'last_Player_ScoretoScore_Games_len_ave_left',
#        'last_Player_Win_Games_len_ave_left',
#        'last_Player_Games_len_Games_len_ave_left', 'Player_left',
#        'last_Player_Score_cumsum_right',
#        'last_Player_ScoretoScore_cumsum_right', 'last_Player_Win_cumsum_right',
#        'last_Player_Games_len_cumsum_right',
#        'last_Player_Score_Player_num_match_ave_right',
#        'last_Player_ScoretoScore_Player_num_match_ave_right',
#        'last_Player_Win_Player_num_match_ave_right',
# ...

# %%
[i for i in df.columns if 'last' not in i]
# Out:
# ['id',
#  'index_left',
#  'Player_left',
#  'Win_left',
#  'Games_len_left',
#  'datetime_left',
#  'toScore_left',
#  'label_left',
#  'other_label_left',
#  'ScoretoScore_left',
#  'index_right',
#  'Player_right',
#  'Win_right',
#  'Games_len_right',
#  'datetime_right',
#  'toScore_right',
#  'label_right',
#  'other_label_right',
#  'ScoretoScore_right']
